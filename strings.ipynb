# %%
# 1. Calculate string length.

# Write a Python program to calculate the length of a string.

string =  "Hello, World!"
print(len(string))
# Out:
# 13

# %%
# 2. Count character frequency in a string.

# Write a Python program to count the number of characters (character frequency) in a string.
# Sample String : google.com'
# Expected Result : {'g': 2, 'o': 3, 'l': 1, 'e': 1, '.': 1, 'c': 1, 'm': 1}

string = "google.com"
freq= {}
for char in string:
    if char in freq:
        freq[char] += 1
    else:
        freq[char] = 1
print(freq)
# Out:
# {'g': 2, 'o': 3, 'l': 1, 'e': 1, '.': 1, 'c': 1, 'm': 1}

# %%
# 3. Get string of first and last 2 chars.

# Write a Python program to get a string made of the first 2 and last 2 characters of a given string. If the string length is less than 2, return the empty string instead.
# Sample String : 'w3resource'
# Expected Result : 'w3ce'
# Sample String : 'w3'
# Expected Result : 'w3w3'
# Sample String : ' w'
# Expected Result : Empty String

def first_last(string):
    if len(string) < 2:
        return ""
    else:
        return string[:2] + string[-2:]
    
print(first_last(input("Enter a string: ")))
# Out:
# suya

# %%
# 4. Replace first char occurrences with $.

# Write a Python program to get a string from a given string where all occurrences of its first char have been changed to '$', 
# except the first char itself.
# Sample String : 'restart'
# Expected Result : 'resta$t'

def replace(string):
    first_char = string[0]
    string =  string.replace(first_char, '$')
    string = first_char + string[1:] 
    return string 

print(replace(input("Enter a string: ")))
# Out:
# anusshk$

# %%
# 5. Swap first 2 chars of 2 strings.

# Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string.
# Sample String : 'abc', 'xyz'
# Expected Result : 'xyc abz'

def swap(str1, str2):
    str3 = str1[:2] + str2[2:] + " " + str2[:2] + str1[2:]
    return str3

print(swap(input("Enter first string: "), input("Enter second string: ")))
# Out:
# sunam purya

# %%
# 6. Add ing or ly to a string.

# Write a Python program to add 'ing' at the end of a given string (length should be at least 3). 
# If the given string already ends with 'ing', add 'ly' instead. 
# If the string length of the given string is less than 3, leave it unchanged.
# Sample String : 'abc'
# Expected Result : 'abcing'
# Sample String : 'string'
# Expected Result : 'stringly'

def add_ing_ly(string):
    if len(string)<3:
        return string
    elif string.endswith("ing"):
        return string + "ly"
    else :
        return string +"ing"
    

print(add_ing_ly(input("Enter the string = ")))
# Out:
# stringly

# %%
# 7. Replace 'not'...'poor' with 'good'.

# Write a Python program to find the first appearance of the substrings 'not' and 'poor' in a given string. 
# If 'not' follows 'poor', replace the whole 'not'...'poor' substring with 'good'. Return the resulting string.
# Sample String : 'The lyrics is not that poor!'
# 'The lyrics is poor!'
# Expected Result : 'The lyrics is good!'
# 'The lyrics is poor!'

def replace_not_poor(string):
    snot  = string.find("not")
    spoor = string.find('poor')
    if spoor > snot and snot > 0 and spoor > 0:
        string =  string.replace(string[snot:(spoor+4)], "good")
        return string
    
    else :
        return string
    
print(replace_not_poor(input("Enter the string = ")))
# Out:
# the weather is good

# %%
# 8. Find longest word in a list.

# Write a Python function that takes a list of words and return the longest word and the length of the longest one.
# Sample Output:
# Longest word: Exercises
# Length of the longest word: 9


def find_longest_word(words_list):
    
    word_len = []

    
    for n in words_list:
        
        word_len.append((len(n), n))

   
    word_len.sort()


    return word_len[-1][0], word_len[-1][1]


result = find_longest_word(["PHP", "Exercises", "Backend"])


print("\nLongest word: ", result[1])
print("Length of the longest word: ", result[0])
# Out:
# Longest word:  Exercises
# Length of the longest word:  9

# %%
# 9. Remove nth character from a string.

# Write a Python program to remove the nth index character from a nonempty string.

def remove_char(string, n):
    return string[:n] + string[n+1:]

# Input
text = input("Enter a string: ")
index = int(input("Enter the index to remove: "))

# Check if the index is valid
if 0 <= index < len(text):
    print("Result:", remove_char(text, index))
else:
    print("Invalid index!")
# Out:
# Result: helo

# %%
# 10. Swap first and last chars of a string.

# Write a Python program to change a given string to a newly string where the first and last chars have been exchanged.

def exchange_char(string):
    return string[-1]+ string[1:-1] + string[0]

text = input("enter the string = ")
print(exchange_char(text))
# Out:
# aurys

# %%
# 11. Remove odd index chars from a string.

# Write a Python program to remove characters that have odd index values in a given string.

def remove_odd_indexes(string):
    result = ""

    for i in range(len(string)):
        if i % 2 != 0:      
            result += string[i]

    return result


text = input("Enter a string: ")
print("New string:", remove_odd_indexes(text))
# Out:
# New string: aefl

# %%
# 12. Count word occurrences in a sentence.

# Write a Python program to count the occurrences of each word in a given sentence.

def count_words(sentence):
    words = sentence.split()
    count = {}

    for word in words:
        if word in count:
            count[word] += 1
        else:
            count[word] = 1

    return count

sentence = input("Enter a sentence: ")
print(count_words(sentence))
# Out:
# {'hy': 1, 'my': 1, 'name': 1, 'is': 1, 'surya': 1, 'pratap': 1, 'singh': 1, ',': 1, 'here': 1, "i'm": 1, 'practising': 1, 'python': 1, 'questions': 1}

# %%
# 13. Display input in upper and lower case.

# Write a Python script that takes input from the user and displays that input back in upper and lower cases.
text = input("Enter a string: ")

print("Upper case:", text.upper())
print("Lower case:", text.lower())
# Out:
# Upper case: HELLO
# Lower case: hello

# %%
# 14. Sort distinct words in comma-separated input.

# Write a Python program that accepts a comma-separated sequence of words as input and prints the distinct words in sorted form (alphanumerically).
# Sample Words : red, white, black, red, green, black
# Expected Result : black, green, red, white,red

words = input("Enter comma-separated words: ")

word_list = words.split(",")

unique_words = sorted(set(word.strip() for word in word_list))

print(",".join(unique_words))
# Out:
# hello. my,is,name,surya

# %%
# 16. Insert string into middle of another.

# Write a Python function to insert a string in the middle of a string.
# Sample function and result :
# insert_sting_middle('[[]]<<>>', 'Python') -> [[Python]]
# insert_sting_middle('{{}}', 'PHP') -> {{PHP}}

def insert_middle(str1, str2):
    middle = len(str1) // 2
    return str1[:middle] + str2 + str1[middle:]

str1 = input("Enter the first string: ")
str2 = input("Enter the second string: ")

print(insert_middle(str1, str2))
# Out:
# [[[php]]]

# %%
# 17. Repeat last 2 chars of a string 4 times.

# Write a Python function to get a string made of 4 copies of the last two characters of a specified string (length must be at least 2).
# Sample function and result :
# insert_end('Python') -> onononon
# insert_end('Exercises') -> eseseses

def repeat_word(str):
    new= str[-2:]
    return new+new+new+new

print(repeat_word(input("enter the string = ")))
# Out:
# yayayaya

# %%
# 18. Get first 3 chars of a string.

# Write a Python function to get a string made of the first three characters of a specified string. If the length of the string is less than 3, return the original string.
# Sample function and result :
# first_three('ipy') -> ipy
# first_three('python') -> pyt

def first_three(str):
      if len(str)>3:
         return str[:3]

      else:
        return str
      

print(first_three(input("enter the string = ")))
# Out:
# sur

# %%
# 19. Get substring before a specific character.

# Write a Python program to get the last part of a string before a specified character.
# https://www.w3resource.com/python-exercises
# https://www.w3resource.com/python

string = "https://www.w3resource.com/python-exercises"
char = "/"

index = string.rfind(char)

if index != -1:
    print(string[:index])
else:
    print("Character not found")
# Out:
# https://www.w3resource.com

# %%
# 20. Reverse string if length is a multiple of 4.

# Write a Python function to reverse a string if its length is a multiple of 4.

def reverse_if_multiple_of_4(string):
    if len(string) % 4 == 0:
        return string[::-1]   # Reverse the string
    return string             # Return unchanged if length is not a multiple of 4

# Example
text = input("Enter a string: ")
print("Result:", reverse_if_multiple_of_4(text))
# Out:
# Result: oleh

# %%
# 21. Even or Odd Checker

# Write a Python program that determines whether a given number (accepted from the user) is even or odd, and prints an appropriate message to the user.

a = int(input("Eter your number = "))
if a % 2 == 0:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# The number is odd

# %%
# 22. Count 4 in List

# Write a Python program to count the number 4 in a given list.

numbers = [1, 4, 6, 4, 7, 4, 9]

count = numbers.count(4)

print("Number of 4s:", count)
# Out:
# Number of 4s: 3

# %%
# 23. String Prefix Copies

# Write a Python program to get n (non-negative integer) copies of the first 2 characters of a given string. 
# Return n copies of the whole string if the length is less than 2.

def return_n(text,n):
    if len(text)>=2:
        return text[0:2]*n
    else:
        return text*n
    
word = input("ENTER THE STIRNG = ")
a = int(input("ENTER THE NUMBER OF COPIES = "))
print(return_n(word,a))
# Out:
# sususu

# %%
# 24. Vowel Tester

# Write a Python program to test whether a passed letter is a vowel or not.

letter = input("Enter a letter: ")

if letter.lower() in "aeiou":
    print("It is a vowel.")
else:
    print("It is not a vowel.")
# Out:
# It is not a vowel.

# %%
# 25. Value in Group Tester

# Write a Python program that checks whether a specified value is contained within a group of values.
# Test  Data :
# 3 -> [1, 5, 8, 3] : True
# -1 -> [1, 5, 8, 3] : False

def check_num(values, num):
    if num in values:
        print(True)
    else:
        print(False)

numbers = list(map(int, input("Enter numbers: ").split()))

value = int(input("Enter the number to be checked: "))

check_num(numbers, value)
# Out:
# True

# %%
# 26. List Histogram

# Write a Python program to create a histogram from a given list of integers.

number = list(map(int,input("Enter the Integers =" ).split()))

for i in number:
    print("*"*i)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
